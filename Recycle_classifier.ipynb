# %%
# Setup & Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, EfficientNetB0
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
from collections import Counter
import json

if tf.config.list_physical_devices('GPU'):
    print("GPU is available and will be used.")
    print("Device:", tf.config.list_physical_devices('GPU')[0])
else:
    print("GPU is NOT available. Go to Runtime → Change runtime type → GPU.")

#  Paths and Parameters
base_path = './drive/MyDrive/trashnet/stage2'
model_save_dir = './drive/MyDrive/trashnet/models'
img_size = (128, 128)
batch_size = 32
input_shape = img_size + (3,)
epochs = 25

# Data Loaders
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_generator = datagen.flow_from_directory(
    base_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Performance Tracking Setup
model_performance = []

def record_model_performance(name, description, input_size, parameter_count, accuracy):
    global model_performance
    model_performance.append([name, description, input_size, parameter_count, accuracy])

def plot_model_performance():
    names, params, accs = [], [], []
    for i in range(len(model_performance)):
        names.append(f"{model_performance[i][0]} {model_performance[i][2]}")
        params.append(model_performance[i][3])
        accs.append(model_performance[i][4])
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.scatter(params, accs)
    ax.set_xlabel('Number of Parameters')
    ax.set_ylabel('Accuracy')
    for i, txt in enumerate(names):
        ax.annotate(txt, (params[i], accs[i] + 0.001))

def print_model_performance():
    print('{0:10s} {1:20s} {2:>12s} {3:>16s} {4:>9s}'.format("name", "description", "input size", "parameter count", "accuracy"))
    for i in range(len(model_performance)):
        print('{0:10s} {1:20s} {2:>12d} {3:>16d} {4:>9.5f}'.format(
            model_performance[i][0],
            model_performance[i][1],
            model_performance[i][2],
            model_performance[i][3],
            model_performance[i][4]))
    plot_model_performance()

# Model Build (2 models)
def build_model(name):
    base_model = MobileNetV2 if name == "MobileNetV2" else EfficientNetB0
    base = base_model(input_shape=input_shape, include_top=False, weights='imagenet')
    base.trainable = False

    inputs = Input(shape=input_shape)
    x = base(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(train_generator.num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Train & Evaluate Both Models
models_to_run = ["MobileNetV2", "EfficientNetB0"]

# Print class distribution
print("Class distribution (training):", Counter(train_generator.classes))

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

for model_name in models_to_run:
    print(f"\nTraining {model_name}...\n")
    model = build_model(model_name)

    # Compile with lower initial learning rate
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

    # Initial training with frozen base
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=10,
        steps_per_epoch=train_generator.samples // batch_size,
        validation_steps=val_generator.samples // batch_size,
        callbacks=[early_stop]
    )

    # Fine-tuning (unfreeze base model)
    print(f"\nFine-tuning {model_name}...\n")
    model.get_layer(index=1).trainable = True  # Unfreeze base model
    model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

    history_finetune = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=15,
        steps_per_epoch=train_generator.samples // batch_size,
        validation_steps=val_generator.samples // batch_size,
        callbacks=[early_stop]
    )

    # Final Evaluation
    score = model.evaluate(val_generator)
    print(f"{model_name} Accuracy: {score[1]:.4f}, Loss: {score[0]:.4f}")

    record_model_performance(
        name=model_name,
        description="Multiclass TrashNet (FT)",
        input_size=img_size[0],
        parameter_count=model.count_params(),
        accuracy=score[1]
    )

    # Save the trained model
    os.makedirs(model_save_dir, exist_ok=True)
    model_path = os.path.join(model_save_dir, f"{model_name}_trashnet.h5")
    model.save(model_path)
    print(f"Saved model to {model_path}")

    # Save training history
    history_all = {
        "loss": history.history['loss'] + history_finetune.history['loss'],
        "val_loss": history.history['val_loss'] + history_finetune.history['val_loss'],
        "accuracy": history.history['accuracy'] + history_finetune.history['accuracy'],
        "val_accuracy": history.history['val_accuracy'] + history_finetune.history['val_accuracy']
    }
    history_path = os.path.join(model_save_dir, f"{model_name}_history.json")
    with open(history_path, "w") as f:
        json.dump(history_all, f)
    print(f"Saved training history to {history_path}")

    # Per-Class Accuracy & Confusion Matrix
    print(f"\nPer-Class Metrics for {model_name}:")

    val_generator.reset()
    y_true, y_pred = [], []
    for i in range(len(val_generator)):
        x_batch, y_batch = val_generator[i]
        preds = model.predict(x_batch)
        y_true.extend(np.argmax(y_batch, axis=1))
        y_pred.extend(np.argmax(preds, axis=1))
        if (i + 1) * batch_size >= val_generator.samples:
            break

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    class_labels = list(val_generator.class_indices.keys())

    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f"{model_name} - Confusion Matrix")
    plt.show()

    report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
    report_df = pd.DataFrame(report).transpose().round(4)
    display(report_df)

# Final Summary
print("\nModel Performance Summary:")
print_model_performance()
# Out:
# Mounted at /content/drive
# GPU is NOT available. Go to Runtime → Change runtime type → GPU.
# Found 9447 images belonging to 4 classes.
# Found 2360 images belonging to 4 classes.
# Class distribution (training): Counter({np.int32(0): 3107, np.int32(2): 2902, np.int32(3): 2074, np.int32(1): 1364})
#
# Training MobileNetV2...
#
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2839s 10s/step - accuracy: 0.4835 - loss: 1.2733 - val_accuracy: 0.7307 - val_loss: 0.7037
# Epoch 2/10
#   1/295 ━━━━━━━━━━━━━━━━━━━━ 1:55 394ms/step - accuracy: 0.7812 - loss: 0.7193
# ...
